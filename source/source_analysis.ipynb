# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('./2021-2022 NBA Player Stats - Playoffs.csv',encoding="Windows-1252", delimiter=";")
dataset.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
dataset.drop('Rk',axis=1,inplace=True)
dataset.describe()
# Out:
#               Age           G          GS          MP          FG         FGA  \
# count  217.000000  217.000000  217.000000  217.000000  217.000000  217.000000
# mean    26.589862    8.161290    3.778802   19.477419    3.056221    6.745622
# std      4.238545    5.008953    5.391773   12.849099    2.694227    5.838640
# min     19.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     23.000000    5.000000    0.000000    7.600000    1.000000    2.000000
# 50%     26.000000    6.000000    0.000000   18.400000    2.300000    4.700000
# 75%     29.000000   12.000000    6.000000   30.800000    4.600000   10.000000
# max     38.000000   19.000000   19.000000   44.000000   12.200000   23.800000
#
#               FG%          3P         3PA         3P%  ...         FT%  \
# count  217.000000  217.000000  217.000000  217.000000  ...  217.000000
# mean     0.435908    0.936866    2.702765    0.269677  ...    0.619618
# ...

# %%
sns.set_theme(style="ticks")
sns.set(rc={"figure.dpi":1000, 'savefig.dpi':1000})
plt.figure(figsize=(15,15))
sns.boxplot(data=dataset)
# Out:
# <AxesSubplot:>
